# %%
library("stylo")
# Out:
# ### stylo version: 0.7.4 ###
#
# If you plan to cite this software (please do!), use the following reference:
#     Eder, M., Rybicki, J. and Kestemont, M. (2016). Stylometry with R:
#     a package for computational text analysis. R Journal 8(1): 107-121.
#     <https://journal.r-project.org/archive/2016/RJ-2016-007/index.html>
#
# To get full BibTeX entry, type: citation("stylo")

# %%
articles <- load.corpus(files = "all", corpus.dir = "files/prose/", encoding = "UTF-8")

# %%
tokenized.corpus <- txt.to.words(articles, preserve.case = FALSE)
grams <- txt.to.features(tokenized.corpus, ngram.size = 3, features = "c")

# %%
data <- grams
clevel <- 25
sliced.corpus <- make.samples(data, sampling = "random.sampling", sample.size = 150)
# Out:
# AOV_10.txt
#
# 	- text length (in words): 5528
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_154.txt
#
# 	- text length (in words): 5141
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_16.txt
#
# 	- text length (in words): 989
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_161.txt
#
# 	- text length (in words): 5479
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_169.txt
#
# 	- text length (in words): 3642
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_175.txt
#
# 	- text length (in words): 7757
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_179.txt
#
# 	- text length (in words): 4430
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_186.txt
#
# 	- text length (in words): 18442
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_188.txt
#
# 	- text length (in words): 11442
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_20.txt
#
# 	- text length (in words): 6446
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_21.txt
#
# 	- text length (in words): 4993
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_24.txt
#
# 	- text length (in words): 7864
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_25.txt
#
# 	- text length (in words): 2280
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_26.txt
#
# 	- text length (in words): 1688
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_3.txt
#
# 	- text length (in words): 2939
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_33.txt
#
# 	- text length (in words): 3602
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_36.txt
#
# 	- text length (in words): 6653
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_40.txt
#
# 	- text length (in words): 17878
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_45.txt
#
# 	- text length (in words): 13389
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_48.txt
#
# 	- text length (in words): 7645
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_50.txt
#
# 	- text length (in words): 10582
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_54.txt
#
# 	- text length (in words): 11624
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_60.txt
#
# 	- text length (in words): 8894
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_65.txt
#
# 	- text length (in words): 8111
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_7.txt
#
# 	- text length (in words): 9332
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_71.txt
#
# 	- text length (in words): 7454
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_87.txt
#
# 	- text length (in words): 17571
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# AOV_93.txt
#
# 	- text length (in words): 8905
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_100.txt
#
# 	- text length (in words): 4888
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_103.txt
#
# 	- text length (in words): 5641
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_111.txt
#
# 	- text length (in words): 4794
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_119.txt
#
# 	- text length (in words): 5649
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_121.txt
#
# 	- text length (in words): 2054
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_126.txt
#
# 	- text length (in words): 12031
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_128.txt
#
# 	- text length (in words): 240
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_129.txt
#
# 	- text length (in words): 969
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_131.txt
#
# 	- text length (in words): 2844
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_141.txt
#
# 	- text length (in words): 3260
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_151.txt
#
# 	- text length (in words): 4545
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_156.txt
#
# 	- text length (in words): 11351
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_160.txt
#
# 	- text length (in words): 5221
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_164.txt
#
# 	- text length (in words): 6014
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_165.txt
#
# 	- text length (in words): 9231
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_173.txt
#
# 	- text length (in words): 3967
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_66.txt
#
# 	- text length (in words): 5624
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_79.txt
#
# 	- text length (in words): 10062
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_9.txt
#
# 	- text length (in words): 846
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# HISe_95.txt
#
# 	- text length (in words): 3571
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_101.txt
#
# 	- text length (in words): 8581
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_105.txt
#
# 	- text length (in words): 4518
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_107.txt
#
# 	- text length (in words): 4716
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_108.txt
#
# 	- text length (in words): 6276
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_110.txt
#
# 	- text length (in words): 9231
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_118.txt
#
# 	- text length (in words): 6846
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_12.txt
#
# 	- text length (in words): 12272
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_123.txt
#
# 	- text length (in words): 8944
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_124.txt
#
# 	- text length (in words): 19486
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_127.txt
#
# 	- text length (in words): 9361
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_132.txt
#
# 	- text length (in words): 2327
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_133.txt
#
# 	- text length (in words): 22762
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_134.txt
#
# 	- text length (in words): 3604
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_135.txt
#
# 	- text length (in words): 15164
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_136.txt
#
# 	- text length (in words): 8364
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_138.txt
#
# 	- text length (in words): 7897
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_139.txt
#
# 	- text length (in words): 6492
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_142.txt
#
# 	- text length (in words): 2882
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_143.txt
#
# 	- text length (in words): 3877
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_144.txt
#
# 	- text length (in words): 9052
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_145.txt
#
# 	- text length (in words): 8812
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_148.txt
#
# 	- text length (in words): 5313
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_150.txt
#
# 	- text length (in words): 10537
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_153.txt
#
# 	- text length (in words): 7050
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_157.txt
#
# 	- text length (in words): 923
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_158.txt
#
# 	- text length (in words): 5785
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_162.txt
#
# 	- text length (in words): 5960
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_170.txt
#
# 	- text length (in words): 6827
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_176.txt
#
# 	- text length (in words): 5427
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_18.txt
#
# 	- text length (in words): 13497
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_181.txt
#
# 	- text length (in words): 10539
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_189.txt
#
# 	- text length (in words): 5649
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_2.txt
#
# 	- text length (in words): 16526
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_23.txt
#
# 	- text length (in words): 9368
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_32.txt
#
# 	- text length (in words): 7451
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_39.txt
#
# 	- text length (in words): 9136
#
# 	- nr. of random samples: 1
# 	- sample length: 150
#
# PBH_44.txt
#
# 	- text length (in words): 7212
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_46.txt
#
# 	- text length (in words): 5374
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_49.txt
#
# 	- text length (in words): 10921
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_53.txt
#
# 	- text length (in words): 9582
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_58.txt
#
# 	- text length (in words): 18705
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_6.txt
#
# 	- text length (in words): 6677
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_64.txt
#
# 	- text length (in words): 3386
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_67.txt
#
# 	- text length (in words): 1909
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_69.txt
#
# 	- text length (in words): 9805
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_72.txt
#
# 	- text length (in words): 8497
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_78.txt
#
# 	- text length (in words): 9264
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_81.txt
#
# 	- text length (in words): 9703
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_82.txt
#
# 	- text length (in words): 9715
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_86.txt
#
# 	- text length (in words): 10850
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_90.txt
#
# 	- text length (in words): 5334
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# PBH_94.txt
#
# 	- text length (in words): 3751
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_1.txt
#
# 	- text length (in words): 1353
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_11.txt
#
# 	- text length (in words): 1272
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_112.txt
#
# 	- text length (in words): 155
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_113.txt
#
# 	- text length (in words): 7348
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_114.txt
#
# 	- text length (in words): 683
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_117.txt
#
# 	- text length (in words): 198
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_147.txt
#
# 	- text length (in words): 3046
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_168.txt
#
# 	- text length (in words): 4751
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_17.txt
#
# 	- text length (in words): 1587
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_174.txt
#
# 	- text length (in words): 2090
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_190.txt
#
# 	- text length (in words): 552
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_22.txt
#
# 	- text length (in words): 1715
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_38.txt
#
# 	- text length (in words): 2013
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_42.txt
#
# 	- text length (in words): 336
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_57.txt
#
# 	- text length (in words): 2048
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_62.txt
#
# 	- text length (in words): 1746
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150
#
# unknown_68.txt
#
# 	- text length (in words): 1316
#
# 	- nr. of random samples: 1
#
# 	- sample length: 150

# %%
frequent.features <- make.frequency.list(data)
freqs <- make.table.of.frequencies(data, features = frequent.features)
culled.freqs <- perform.culling(freqs, culling.level = clevel)
#my.stylometric.test = stylo(frequencies = culled.freqs, gui = TRUE, path = NULL)
# Out:
# processing  117  text samples
#
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
#
#
# combining frequencies into a table...

# %%
rownames(freqs)
# Out:
#   [1] "AOV_10.txt"      "AOV_154.txt"     "AOV_16.txt"      "AOV_161.txt"
#   [5] "AOV_169.txt"     "AOV_175.txt"     "AOV_179.txt"     "AOV_186.txt"
#   [9] "AOV_188.txt"     "AOV_20.txt"      "AOV_21.txt"      "AOV_24.txt"
#  [13] "AOV_25.txt"      "AOV_26.txt"      "AOV_3.txt"       "AOV_33.txt"
#  [17] "AOV_36.txt"      "AOV_40.txt"      "AOV_45.txt"      "AOV_48.txt"
#  [21] "AOV_50.txt"      "AOV_54.txt"      "AOV_60.txt"      "AOV_65.txt"
#  [25] "AOV_7.txt"       "AOV_71.txt"      "AOV_87.txt"      "AOV_93.txt"
#  [29] "HISe_100.txt"    "HISe_103.txt"    "HISe_111.txt"    "HISe_119.txt"
#  [33] "HISe_121.txt"    "HISe_126.txt"    "HISe_128.txt"    "HISe_129.txt"
#  [37] "HISe_131.txt"    "HISe_141.txt"    "HISe_151.txt"    "HISe_156.txt"
#  [41] "HISe_160.txt"    "HISe_164.txt"    "HISe_165.txt"    "HISe_173.txt"
#  [45] "HISe_66.txt"     "HISe_79.txt"     "HISe_9.txt"      "HISe_95.txt"
#  [49] "PBH_101.txt"     "PBH_105.txt"     "PBH_107.txt"     "PBH_108.txt"
#  [53] "PBH_110.txt"     "PBH_118.txt"     "PBH_12.txt"      "PBH_123.txt"
#  [57] "PBH_124.txt"     "PBH_127.txt"     "PBH_132.txt"     "PBH_133.txt"
#  [61] "PBH_134.txt"     "PBH_135.txt"     "PBH_136.txt"     "PBH_138.txt"
#  [65] "PBH_139.txt"     "PBH_142.txt"     "PBH_143.txt"     "PBH_144.txt"
#  [69] "PBH_145.txt"     "PBH_148.txt"     "PBH_150.txt"     "PBH_153.txt"
#  [73] "PBH_157.txt"     "PBH_158.txt"     "PBH_162.txt"     "PBH_170.txt"
#  [77] "PBH_176.txt"     "PBH_18.txt"      "PBH_181.txt"     "PBH_189.txt"
#  [81] "PBH_2.txt"       "PBH_23.txt"      "PBH_32.txt"      "PBH_39.txt"
#  [85] "PBH_44.txt"      "PBH_46.txt"      "PBH_49.txt"      "PBH_53.txt"
#  [89] "PBH_58.txt"      "PBH_6.txt"       "PBH_64.txt"      "PBH_67.txt"
#  [93] "PBH_69.txt"      "PBH_72.txt"      "PBH_78.txt"      "PBH_81.txt"
#  [97] "PBH_82.txt"      "PBH_86.txt"      "PBH_90.txt"      "PBH_94.txt"
# [101] "unknown_1.txt"   "unknown_11.txt"  "unknown_112.txt" "unknown_113.txt"
# [105] "unknown_114.txt" "unknown_117.txt" "unknown_147.txt" "unknown_168.txt"
# [109] "unknown_17.txt"  "unknown_174.txt" "unknown_190.txt" "unknown_22.txt"
# [113] "unknown_38.txt"  "unknown_42.txt"  "unknown_57.txt"  "unknown_62.txt"
# [117] "unknown_68.txt"

# %%
text_name = grep("unknown", rownames(freqs))

# %%
text_name
# Out:
#  [1] 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117

# %%
my_text_to_be_tested = freqs[text_name,]

# %%
my_frequency_table = freqs[-c(text_name),]

# %%
for (x in text_name) {
    print(rownames(freqs)[x])
    imposters(reference.set = my_frequency_table, test = freqs[x,])
}
# Out:
# [1] "unknown_1.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.23
#
# HISe 	 0.88
#
# PBH 	 0.41
# [1] "unknown_11.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.28
#
# HISe 	 0.88
#
# PBH 	 0.39
# [1] "unknown_112.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.13
#
# HISe 	 1
#
# PBH 	 0.35
# [1] "unknown_113.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.1
#
# HISe 	 0.62
#
# PBH 	 0.94
# [1] "unknown_114.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.17
#
# HISe 	 0.92
#
# PBH 	 0.58
# [1] "unknown_117.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.13
#
# HISe 	 1
#
# PBH 	 0.46
# [1] "unknown_147.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.21
#
# HISe 	 0.8
#
# PBH 	 0.58
# [1] "unknown_168.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.19
#
# HISe 	 0.98
#
# PBH 	 0.33
# [1] "unknown_17.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.46
#
# HISe 	 0.71
#
# PBH 	 0.53
# [1] "unknown_174.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.45
#
# HISe 	 0.72
#
# PBH 	 0.52
# [1] "unknown_190.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.13
#
# HISe 	 1
#
# PBH 	 0.43
# [1] "unknown_22.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.5
#
# HISe 	 0.71
#
# PBH 	 0.48
# [1] "unknown_38.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.77
#
# HISe 	 0.34
#
# PBH 	 0.58
# [1] "unknown_42.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.13
#
# HISe 	 1
#
# PBH 	 0.46
# [1] "unknown_57.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.64
#
# HISe 	 0.73
#
# PBH 	 0.23
# [1] "unknown_62.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.64
#
# HISe 	 0.82
#
# PBH 	 0.26
# [1] "unknown_68.txt"
# No candidate set specified; testing the following classes (one at a time):
#
#   AOV   HISe   PBH
#
#
#
#
# Testing a given candidate against imposters...
#
#
# AOV 	 0.15
#
# HISe 	 0.85
#
# PBH 	 0.5
