# %%
import pandas as pd
import networkx as nx
import dhlab.graph_networkx_louvain as gnl

# %%
handf = "./output/handwritten_signatures/handwritten_signatures_CA_100_MFWs_Culled_0__Classic Delta_EDGES.csv"
combof = "./output/combo/combo_CA_100_MFWs_Culled_0__Classic Delta_EDGES.csv"
printf = "./output/printed_signatures/printed_signatures_CA_100_MFWs_Culled_0__Classic Delta_EDGES.csv"

# %%
graph_data = pd.read_csv(combof)

# %%
adj = graph_data.pivot("Source", "Target", "Weight").fillna(0)

G = nx.from_pandas_adjacency(adj)

gnl.show_graph(G, fontsize=10)

# %%
gnl.show_communities(G)
# Out:
# AOV_44-AOV_39 :  AOV_44, AOV_39, AOV_174, AOV_6, AOV_160, AOV_9, AOV_59, AOV_20, AOV_24, AOV_2, AOV_32, AOV_13, AOV_19, AOV_53, AOV_178, unknown_56, AOV_168, AOV_64, PBH_93, HISe_94, AOV_153
#
# PBH_154-PBH_165 :  PBH_154, PBH_165, HISe_136, PBH_186, PBH_158, PBH_170, PBH_151, PBH_162, PBH_181, unknown_101, HISe_115, PBH_176, unknown_51, HISe_40, PBH_184, HISe_74, HISe_18, AOV_15, HISe_12, PBH_28, unknown_84, unknown_16, HISe_145, HISe_83, HISe_139, unknown_79, unknown_42, HISe_50, HISe_7, unknown_46
#
# PBH_17-AOV_86 :  PBH_17, AOV_86, PBH_1, AOV_49, PBH_188, AOV_185, PBH_134, PBH_169, PBH_57, PBH_135, PBH_144, AOV_92, HISe_125, AOV_47, PBH_152, PBH_5, AOV_35, AOV_187, PBH_133, unknown_21, unknown_67, HISe_99, HISe_102, unknown_113, HISe_128, unknown_173, PBH_106, unknown_0, PBH_66, PBH_138
#
# AOV_70-PBH_180 :  AOV_70, PBH_180, PBH_149, PBH_161, AOV_23, PBH_137, PBH_143, unknown_30, PBH_157, HISe_87
#
# ...

# %%
gnl.show_cliques(G)
# Out:
# (3, 1) HISe_114, HISe_8, HISe_155
#
# (3, 2) PBH_63, PBH_85, PBH_91, PBH_104, HISe_164, PBH_71
#
# (3, 3) PBH_154, unknown_79, PBH_151, HISe_115, HISe_50
#
# (3, 4) PBH_57, AOV_47, PBH_100, PBH_134, PBH_48, PBH_133, AOV_187, AOV_49, PBH_89, AOV_35, AOV_86, PBH_156, PBH_123, PBH_68, HISe_118, PBH_152, PBH_52, AOV_92, HISe_102, HISe_114, PBH_17, PBH_22, PBH_109, PBH_169, unknown_21, PBH_96, AOV_178, unknown_37, PBH_126, PBH_11, AOV_174, AOV_185, PBH_188, HISe_128, unknown_0, PBH_80, PBH_43, PBH_135, HISe_125, PBH_71, AOV_23, PBH_144, PBH_66, PBH_106, PBH_1, PBH_107, PBH_103, PBH_31, PBH_38, PBH_5, PBH_117, PBH_138, PBH_132, AOV_70, PBH_142
#
# (3, 5) AOV_64, AOV_153, AOV_9, AOV_59, AOV_6, AOV_44, unknown_56, AOV_160, AOV_86, AOV_32, AOV_2, AOV_49, AOV_39
#
# (3, 6) PBH_147, unknown_61, PBH_103
#
# (3, 7) PBH_132, PBH_137, unknown_30
#
# (3, 8) HISe_65, HISe_78, PBH_81, HISe_110
#
# ...
