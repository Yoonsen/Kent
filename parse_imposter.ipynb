# %%
import re
import pandas as pd

# %%
imposter_analysis="""[1] "unknown_1.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.23

HISe 	 0.88

PBH 	 0.41

[1] "unknown_11.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.28

HISe 	 0.88

PBH 	 0.39

[1] "unknown_112.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.13

HISe 	 1

PBH 	 0.35

[1] "unknown_113.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.1

HISe 	 0.62

PBH 	 0.94

[1] "unknown_114.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.17

HISe 	 0.92

PBH 	 0.58

[1] "unknown_117.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.13

HISe 	 1

PBH 	 0.46

[1] "unknown_147.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.21

HISe 	 0.8

PBH 	 0.58

[1] "unknown_168.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.19

HISe 	 0.98

PBH 	 0.33

[1] "unknown_17.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.46

HISe 	 0.71

PBH 	 0.53

[1] "unknown_174.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.45

HISe 	 0.72

PBH 	 0.52

[1] "unknown_190.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.13

HISe 	 1

PBH 	 0.43

[1] "unknown_22.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.5

HISe 	 0.71

PBH 	 0.48

[1] "unknown_38.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.77

HISe 	 0.34

PBH 	 0.58

[1] "unknown_42.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.13

HISe 	 1

PBH 	 0.46

[1] "unknown_57.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.64

HISe 	 0.73

PBH 	 0.23

[1] "unknown_62.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.64

HISe 	 0.82

PBH 	 0.26

[1] "unknown_68.txt"
No candidate set specified; testing the following classes (one at a time):

  AOV   HISe   PBH

 


Testing a given candidate against imposters...


AOV 	 0.15

HISe 	 0.85

PBH 	 0.5
"""

# %%
import re

# %%
imposter_analysis.replace('\n',"#")
# Out:
# '[1] "unknown_1.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.23##HISe \t 0.88##PBH \t 0.41##[1] "unknown_11.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.28##HISe \t 0.88##PBH \t 0.39##[1] "unknown_112.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.13##HISe \t 1##PBH \t 0.35##[1] "unknown_113.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.1##HISe \t 0.62##PBH \t 0.94##[1] "unknown_114.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.17##HISe \t 0.92##PBH \t 0.58##[1] "unknown_117.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.13##HISe \t 1##PBH \t 0.46##[1] "unknown_147.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.21##HISe \t 0.8##PBH \t 0.58##[1] "unknown_168.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.19##HISe \t 0.98##PBH \t 0.33##[1] "unknown_17.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.46##HISe \t 0.71##PBH \t 0.53##[1] "unknown_174.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.45##HISe \t 0.72##PBH \t 0.52##[1] "unknown_190.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.13##HISe \t 1##PBH \t 0.43##[1] "unknown_22.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.5##HISe \t 0.71##PBH \t 0.48##[1] "unknown_38.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.77##HISe \t 0.34##PBH \t 0.58##[1] "unknown_42.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.13##HISe \t 1##PBH \t 0.46##[1] "unknown_57.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.64##HISe \t 0.73##PBH \t 0.23##[1] "unknown_62.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.64##HISe \t 0.82##PBH \t 0.26##[1] "unknown_68.txt"#No candidate set specified; testing the following classes (one at a time):##  AOV   HISe   PBH## ###Testing a given candidate against imposters...###AOV \t 0.15##HISe \t 0.85##PBH \t 0.5#'

# %%
data = re.findall("""(unknown_[0-9]+.txt).*?(AOV) \t (0.[0-9]+).*?(HISe) \t (0.[0-9]+).*?(PBH) \t (0.[0-9]+)""",imposter_analysis.replace('\n','#'))

# %%
datajson = [{'file':d[0], d[1]:d[2], d[3]:d[4], d[5]:d[6]} for d in data]
datajson
# Out:
# [{'file': 'unknown_1.txt', 'AOV': '0.23', 'HISe': '0.88', 'PBH': '0.41'},
#  {'file': 'unknown_11.txt', 'AOV': '0.28', 'HISe': '0.88', 'PBH': '0.39'},
#  {'file': 'unknown_112.txt', 'AOV': '0.13', 'HISe': '0.62', 'PBH': '0.94'},
#  {'file': 'unknown_114.txt', 'AOV': '0.17', 'HISe': '0.92', 'PBH': '0.58'},
#  {'file': 'unknown_117.txt', 'AOV': '0.13', 'HISe': '0.8', 'PBH': '0.58'},
#  {'file': 'unknown_168.txt', 'AOV': '0.19', 'HISe': '0.98', 'PBH': '0.33'},
#  {'file': 'unknown_17.txt', 'AOV': '0.46', 'HISe': '0.71', 'PBH': '0.53'},
#  {'file': 'unknown_174.txt', 'AOV': '0.45', 'HISe': '0.72', 'PBH': '0.52'},
#  {'file': 'unknown_190.txt', 'AOV': '0.13', 'HISe': '0.71', 'PBH': '0.48'},
#  {'file': 'unknown_38.txt', 'AOV': '0.77', 'HISe': '0.34', 'PBH': '0.58'},
#  {'file': 'unknown_42.txt', 'AOV': '0.13', 'HISe': '0.73', 'PBH': '0.23'},
#  {'file': 'unknown_62.txt', 'AOV': '0.64', 'HISe': '0.82', 'PBH': '0.26'},
#  {'file': 'unknown_68.txt', 'AOV': '0.15', 'HISe': '0.85', 'PBH': '0.5'}]

# %%
df = pd.DataFrame(datajson).set_index('file')
df
# Out:
#                   AOV  HISe   PBH
# file
# unknown_1.txt    0.23  0.88  0.41
# unknown_11.txt   0.28  0.88  0.39
# unknown_112.txt  0.13  0.62  0.94
# unknown_114.txt  0.17  0.92  0.58
# unknown_117.txt  0.13   0.8  0.58
# unknown_168.txt  0.19  0.98  0.33
# unknown_17.txt   0.46  0.71  0.53
# unknown_174.txt  0.45  0.72  0.52
# unknown_190.txt  0.13  0.71  0.48
# unknown_38.txt   0.77  0.34  0.58
# unknown_42.txt   0.13  0.73  0.23
# unknown_62.txt   0.64  0.82  0.26
# unknown_68.txt   0.15  0.85   0.5

# %%
df.to_csv('imposter_data.csv')

# %%
df.sort_values(by='HISe', ascending=False).style.background_gradient(axis = 0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4c063">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c063_level0_col0" class="col_heading level0 col0" >AOV</th>
#       <th id="T_4c063_level0_col1" class="col_heading level0 col1" >HISe</th>
#       <th id="T_4c063_level0_col2" class="col_heading level0 col2" >PBH</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >file</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c063_level0_row0" class="row_heading level0 row0" >unknown_168.txt</th>
#       <td id="T_4c063_row0_col0" class="data row0 col0" >0.19</td>
#       <td id="T_4c063_row0_col1" class="data row0 col1" >0.98</td>
#       <td id="T_4c063_row0_col2" class="data row0 col2" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row1" class="row_heading level0 row1" >unknown_114.txt</th>
#       <td id="T_4c063_row1_col0" class="data row1 col0" >0.17</td>
#       <td id="T_4c063_row1_col1" class="data row1 col1" >0.92</td>
#       <td id="T_4c063_row1_col2" class="data row1 col2" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row2" class="row_heading level0 row2" >unknown_1.txt</th>
#       <td id="T_4c063_row2_col0" class="data row2 col0" >0.23</td>
#       <td id="T_4c063_row2_col1" class="data row2 col1" >0.88</td>
#       <td id="T_4c063_row2_col2" class="data row2 col2" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row3" class="row_heading level0 row3" >unknown_11.txt</th>
#       <td id="T_4c063_row3_col0" class="data row3 col0" >0.28</td>
#       <td id="T_4c063_row3_col1" class="data row3 col1" >0.88</td>
#       <td id="T_4c063_row3_col2" class="data row3 col2" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row4" class="row_heading level0 row4" >unknown_68.txt</th>
#       <td id="T_4c063_row4_col0" class="data row4 col0" >0.15</td>
#       <td id="T_4c063_row4_col1" class="data row4 col1" >0.85</td>
#       <td id="T_4c063_row4_col2" class="data row4 col2" >0.5</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row5" class="row_heading level0 row5" >unknown_62.txt</th>
#       <td id="T_4c063_row5_col0" class="data row5 col0" >0.64</td>
#       <td id="T_4c063_row5_col1" class="data row5 col1" >0.82</td>
#       <td id="T_4c063_row5_col2" class="data row5 col2" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row6" class="row_heading level0 row6" >unknown_117.txt</th>
#       <td id="T_4c063_row6_col0" class="data row6 col0" >0.13</td>
#       <td id="T_4c063_row6_col1" class="data row6 col1" >0.8</td>
#       <td id="T_4c063_row6_col2" class="data row6 col2" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row7" class="row_heading level0 row7" >unknown_42.txt</th>
#       <td id="T_4c063_row7_col0" class="data row7 col0" >0.13</td>
#       <td id="T_4c063_row7_col1" class="data row7 col1" >0.73</td>
#       <td id="T_4c063_row7_col2" class="data row7 col2" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row8" class="row_heading level0 row8" >unknown_174.txt</th>
#       <td id="T_4c063_row8_col0" class="data row8 col0" >0.45</td>
#       <td id="T_4c063_row8_col1" class="data row8 col1" >0.72</td>
#       <td id="T_4c063_row8_col2" class="data row8 col2" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row9" class="row_heading level0 row9" >unknown_17.txt</th>
#       <td id="T_4c063_row9_col0" class="data row9 col0" >0.46</td>
#       <td id="T_4c063_row9_col1" class="data row9 col1" >0.71</td>
#       <td id="T_4c063_row9_col2" class="data row9 col2" >0.53</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row10" class="row_heading level0 row10" >unknown_190.txt</th>
#       <td id="T_4c063_row10_col0" class="data row10 col0" >0.13</td>
#       <td id="T_4c063_row10_col1" class="data row10 col1" >0.71</td>
#       <td id="T_4c063_row10_col2" class="data row10 col2" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row11" class="row_heading level0 row11" >unknown_112.txt</th>
#       <td id="T_4c063_row11_col0" class="data row11 col0" >0.13</td>
#       <td id="T_4c063_row11_col1" class="data row11 col1" >0.62</td>
#       <td id="T_4c063_row11_col2" class="data row11 col2" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_4c063_level0_row12" class="row_heading level0 row12" >unknown_38.txt</th>
#       <td id="T_4c063_row12_col0" class="data row12 col0" >0.77</td>
#       <td id="T_4c063_row12_col1" class="data row12 col1" >0.34</td>
#       <td id="T_4c063_row12_col2" class="data row12 col2" >0.58</td>
#     </tr>
#   </tbody>
# </table>
