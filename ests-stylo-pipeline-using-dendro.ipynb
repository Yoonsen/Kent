# %%
library("stylo")
# Out:
# ### stylo version: 0.7.4 ###
#
# If you plan to cite this software (please do!), use the following reference:
#     Eder, M., Rybicki, J. and Kestemont, M. (2016). Stylometry with R:
#     a package for computational text analysis. R Journal 8(1): 107-121.
#     <https://journal.r-project.org/archive/2016/RJ-2016-007/index.html>
#
# To get full BibTeX entry, type: citation("stylo")

# %%
articles <- load.corpus(files = "all", 
                        corpus.dir = "files/combo/", encoding = "UTF-8")

# %%
tokenized.corpus <- txt.to.words(articles, preserve.case = FALSE)
grams <- txt.to.features(tokenized.corpus, ngram.size = 3, features = "c")

# %%
data <- grams
clevel <- 25
sliced.corpus <- make.samples(data, sampling = "random.sampling", sample.size = 100)
# Out:
# AOV_13.txt
#
# 	- text length (in words): 4679
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_15.txt
#
# 	- text length (in words): 991
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_153.txt
#
# 	- text length (in words): 5147
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_160.txt
#
# 	- text length (in words): 5479
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_168.txt
#
# 	- text length (in words): 3642
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_174.txt
#
# 	- text length (in words): 7757
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_178.txt
#
# 	- text length (in words): 4430
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_185.txt
#
# 	- text length (in words): 18442
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_187.txt
#
# 	- text length (in words): 11448
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_19.txt
#
# 	- text length (in words): 6446
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_2.txt
#
# 	- text length (in words): 2939
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_20.txt
#
# 	- text length (in words): 4995
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_23.txt
#
# 	- text length (in words): 7864
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_24.txt
#
# 	- text length (in words): 2282
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_25.txt
#
# 	- text length (in words): 1690
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_32.txt
#
# 	- text length (in words): 3602
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_35.txt
#
# 	- text length (in words): 6653
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_39.txt
#
# 	- text length (in words): 17878
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_44.txt
#
# 	- text length (in words): 13389
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_47.txt
#
# 	- text length (in words): 7645
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_49.txt
#
# 	- text length (in words): 10582
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_53.txt
#
# 	- text length (in words): 11624
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_59.txt
#
# 	- text length (in words): 8894
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_6.txt
#
# 	- text length (in words): 9334
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_64.txt
#
# 	- text length (in words): 8111
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_70.txt
#
# 	- text length (in words): 7454
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_86.txt
#
# 	- text length (in words): 17571
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_9.txt
#
# 	- text length (in words): 5528
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# AOV_92.txt
#
# 	- text length (in words): 8911
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_102.txt
#
# 	- text length (in words): 5641
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_110.txt
#
# 	- text length (in words): 4801
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_114.txt
#
# 	- text length (in words): 8168
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_115.txt
#
# 	- text length (in words): 1201
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_118.txt
#
# 	- text length (in words): 5655
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_119.txt
#
# 	- text length (in words): 4215
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_12.txt
#
# 	- text length (in words): 1486
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_120.txt
#
# 	- text length (in words): 2060
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_125.txt
#
# 	- text length (in words): 12039
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_127.txt
#
# 	- text length (in words): 242
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_128.txt
#
# 	- text length (in words): 975
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_129.txt
#
# 	- text length (in words): 908
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_130.txt
#
# 	- text length (in words): 2846
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_136.txt
#
# 	- text length (in words): 4763
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_139.txt
#
# 	- text length (in words): 2960
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_140.txt
#
# 	- text length (in words): 3266
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_145.txt
#
# 	- text length (in words): 3512
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_150.txt
#
# 	- text length (in words): 4551
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_155.txt
#
# 	- text length (in words): 11359
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_159.txt
#
# 	- text length (in words): 5227
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_163.txt
#
# 	- text length (in words): 6022
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_164.txt
#
# 	- text length (in words): 9239
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_172.txt
#
# 	- text length (in words): 3967
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_18.txt
#
# 	- text length (in words): 1613
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_40.txt
#
# 	- text length (in words): 922
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_50.txt
#
# 	- text length (in words): 1155
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_65.txt
#
# 	- text length (in words): 5628
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_7.txt
#
# 	- text length (in words): 1249
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_74.txt
#
# 	- text length (in words): 4020
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_78.txt
#
# 	- text length (in words): 10069
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_8.txt
#
# 	- text length (in words): 850
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_83.txt
#
# 	- text length (in words): 1789
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_87.txt
#
# 	- text length (in words): 1166
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_94.txt
#
# 	- text length (in words): 3577
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# HISe_99.txt
#
# 	- text length (in words): 4894
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_1.txt
#
# 	- text length (in words): 16526
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_100.txt
#
# 	- text length (in words): 8581
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_103.txt
#
# 	- text length (in words): 9466
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_104.txt
#
# 	- text length (in words): 4524
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_106.txt
#
# 	- text length (in words): 4723
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_107.txt
#
# 	- text length (in words): 6276
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_109.txt
#
# 	- text length (in words): 9231
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_11.txt
#
# 	- text length (in words): 12272
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_117.txt
#
# 	- text length (in words): 6852
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_122.txt
#
# 	- text length (in words): 8950
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_123.txt
#
# 	- text length (in words): 19486
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_126.txt
#
# 	- text length (in words): 9361
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_131.txt
#
# 	- text length (in words): 2327
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_132.txt
#
# 	- text length (in words): 22762
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_133.txt
#
# 	- text length (in words): 3610
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_134.txt
#
# 	- text length (in words): 15170
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_135.txt
#
# 	- text length (in words): 8370
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_137.txt
#
# 	- text length (in words): 7897
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_138.txt
#
# 	- text length (in words): 6492
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_141.txt
#
# 	- text length (in words): 2888
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_142.txt
#
# 	- text length (in words): 3883
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_143.txt
#
# 	- text length (in words): 9052
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_144.txt
#
# 	- text length (in words): 8818
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_147.txt
#
# 	- text length (in words): 5364
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_149.txt
#
# 	- text length (in words): 10537
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_151.txt
#
# 	- text length (in words): 5897
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_152.txt
#
# 	- text length (in words): 7056
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_154.txt
#
# 	- text length (in words): 8444
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_156.txt
#
# 	- text length (in words): 935
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_157.txt
#
# 	- text length (in words): 5785
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_158.txt
#
# 	- text length (in words): 10025
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_161.txt
#
# 	- text length (in words): 5960
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_162.txt
#
# 	- text length (in words): 7048
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_165.txt
#
# 	- text length (in words): 9298
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_169.txt
#
# 	- text length (in words): 6844
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_17.txt
#
# 	- text length (in words): 13497
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_170.txt
#
# 	- text length (in words): 5702
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_175.txt
#
# 	- text length (in words): 5433
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_176.txt
#
# 	- text length (in words): 9131
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_180.txt
#
# 	- text length (in words): 10557
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_181.txt
#
# 	- text length (in words): 6151
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_184.txt
#
# 	- text length (in words): 6665
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_186.txt
#
# 	- text length (in words): 7303
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_188.txt
#
# 	- text length (in words): 5655
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_22.txt
#
# 	- text length (in words): 9368
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_28.txt
#
# 	- text length (in words): 139
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_31.txt
#
# 	- text length (in words): 7451
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_38.txt
#
# 	- text length (in words): 9136
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_43.txt
#
# 	- text length (in words): 7212
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_45.txt
#
# 	- text length (in words): 5380
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_48.txt
#
# 	- text length (in words): 10927
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_5.txt
#
# 	- text length (in words): 6677
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_52.txt
#
# 	- text length (in words): 9582
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_57.txt
#
# 	- text length (in words): 18711
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_63.txt
#
# 	- text length (in words): 3388
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_66.txt
#
# 	- text length (in words): 1911
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_68.txt
#
# 	- text length (in words): 9807
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_71.txt
#
# 	- text length (in words): 8503
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_77.txt
#
# 	- text length (in words): 9270
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_80.txt
#
# 	- text length (in words): 9709
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_81.txt
#
# 	- text length (in words): 9721
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_85.txt
#
# 	- text length (in words): 10856
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_89.txt
#
# 	- text length (in words): 5334
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_91.txt
#
# 	- text length (in words): 3186
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_93.txt
#
# 	- text length (in words): 3759
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# PBH_96.txt
#
# 	- text length (in words): 6785
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_0.txt
#
# 	- text length (in words): 1353
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_10.txt
#
# 	- text length (in words): 1272
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_101.txt
#
# 	- text length (in words): 395
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_111.txt
#
# 	- text length (in words): 163
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_112.txt
#
# 	- text length (in words): 7348
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_113.txt
#
# 	- text length (in words): 683
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_116.txt
#
# 	- text length (in words): 198
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_146.txt
#
# 	- text length (in words): 3046
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_16.txt
#
# 	- text length (in words): 1587
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_167.txt
#
# 	- text length (in words): 4751
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_173.txt
#
# 	- text length (in words): 2097
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_189.txt
#
# 	- text length (in words): 562
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_21.txt
#
# 	- text length (in words): 1715
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_30.txt
#
# 	- text length (in words): 1008
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_37.txt
#
# 	- text length (in words): 2013
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_41.txt
#
# 	- text length (in words): 343
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_42.txt
#
# 	- text length (in words): 942
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_46.txt
#
# 	- text length (in words): 852
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_51.txt
#
# 	- text length (in words): 414
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_56.txt
#
# 	- text length (in words): 2048
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_58.txt
#
# 	- text length (in words): 142
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_61.txt
#
# 	- text length (in words): 1746
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_67.txt
#
# 	- text length (in words): 1316
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_79.txt
#
# 	- text length (in words): 268
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_84.txt
#
# 	- text length (in words): 212
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100
#
# unknown_88.txt
#
# 	- text length (in words): 209
#
# 	- nr. of random samples: 1
#
# 	- sample length: 100

# %%
#help(stylo)

# %%
frequent.features <- make.frequency.list(data)
freqs <- make.table.of.frequencies(data, features = frequent.features)
culled.freqs <- perform.culling(freqs, culling.level = clevel)
my.stylometric.test = stylo(frequencies = culled.freqs, gui = FALSE, path = NULL)
# Out:
# processing  156  text samples
#
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
#
#
# combining frequencies into a table...
#
# using current directory...
#
#
#
#
# culling @ 0	available features (words) 1714
#
# Calculating z-scores...
#
#
# Calculating classic Delta distances...
#
# MFW used:
#
# 100
#
# Processing metadata...
#
#
#
# Assigning plot colors according to file names...
# Plot with title “Kent
#  Cluster Analysis”
